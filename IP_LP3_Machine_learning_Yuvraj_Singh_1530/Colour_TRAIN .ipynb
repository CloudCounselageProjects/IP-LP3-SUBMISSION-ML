# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split

IMG_SIZE = 32
DATADIR = r'E:\COLOURS\train'
CATEGORIES =['Shades_of_Red','Shades_of_Blue','Shades_of_Green']
training_data = []

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    class_num = CATEGORIES.index(category)
    print(class_num)

    for img in os.listdir(path):
        try:
            img_array = cv2.imread(os.path.join(path,img))
            new_array = cv2.resize(img_array,(IMG_SIZE, IMG_SIZE))
            training_data.append([new_array, class_num])
        except Exception as e:
            pass

import random
random.shuffle(training_data)
X = []
y = []

for features, label in training_data:  
    X.append(features) 
    y.append(label)

# X and y are currently of type list (list of python array), we will convert these to numpy array so we can feed it into our model.
X = np.array(X) 
y = np.array(y) 


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D

model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['sparse_categorical_accuracy'])
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
model.save(r"E:\COLOURS\COLOURS_CNN.h5")

loss, acc = model.evaluate(X_test, y_test, verbose = 0)
print("\n\n The Accuracy of the Model is :",acc * 100)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\sw\Anaconda3\envs\tf_gpu\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# 0
# 1
# 2
# Train on 2977 samples, validate on 745 samples
# Epoch 1/10
# 2977/2977 [==============================] - 7s 2ms/sample - loss: 0.4413 - sparse_categorical_accuracy: 0.9342 - val_loss: 0.0091 - val_sparse_categorical_accuracy: 0.9987
# Epoch 2/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0749 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 1.0000
# Epoch 3/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0865 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.1425 - val_sparse_categorical_accuracy: 0.9503
# Epoch 4/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0499 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.0121 - val_sparse_categorical_accuracy: 0.9960
# Epoch 5/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0512 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.4256 - val_sparse_categorical_accuracy: 0.9020
# Epoch 6/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0575 - sparse_categorical_accuracy: 0.9805 - val_loss: 0.0064 - val_sparse_categorical_accuracy: 0.9973
# Epoch 7/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0355 - sparse_categorical_accuracy: 0.9893 - val_loss: 0.0042 - val_sparse_categorical_accuracy: 1.0000
# Epoch 8/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0044 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 0.9987
# Epoch 9/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0852 - sparse_categorical_accuracy: 0.9745 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9973
# Epoch 10/10
# 2977/2977 [==============================] - 4s 1ms/sample - loss: 0.0267 - sparse_categorical_accuracy: 0.9953 - val_loss: 9.3396e-04 - val_sparse_categorical_accuracy: 1.0000
#
#
#  The Accuracy of the Model is : 100.0
